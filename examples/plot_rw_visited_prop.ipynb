# %%
# Setup
# %matplotlib inline
import sys
sys.path.insert(0, '..')

from graph import Graph
from walker import Walker
from simulator import Simulator

# %%
# Set parameters
n = 100
expected_deg = 10
p = expected_deg/n
steps = n

# %%
# Plot visited proportion over time for one graph
Simulator.plot_rw_on_rg_visited_prop(n, p, steps)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wp/svz0rq8n0x10g6tdp4ctz5_80000gn/T/ipykernel_60207/2725470744.py in <module>
#       1 # Plot visited proportion over time
# ----> 2 Simulator.plot_rw_visited_prop(n, p, steps)
#
# AttributeError: type object 'Simulator' has no attribute 'plot_rw_visited_prop'

# %%
# Plot average visited proportion
k = 20
Simulator.plot_rw_on_rg_visited_prop_multi(n, p, steps, k)
