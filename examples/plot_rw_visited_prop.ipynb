# %%
# Setup
# %matplotlib inline
import sys
sys.path.insert(0, '..')

from graph import Graph
from walker import Walker
from simulator import Simulator

# %%
# Set parameters
n = 10000
expected_deg = 10
p = expected_deg/n
steps = n

# %%
# Plot visited proportion over time
Simulator.plot_rw_visited_prop(n, p, steps)
