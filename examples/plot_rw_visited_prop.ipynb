# %%
# Setup
# %matplotlib inline
import sys
import matplotlib as plt
import numpy as np

sys.path.insert(0, '..')
plt.rcParams['figure.figsize'] = [10, 8]

from graph import Graph
from walkers import RandomWalker
from simulator import Simulator

# %%
# Set parameters
n = 1000
expected_deg = 10
p = expected_deg/n
max_c = 0.6 # can be changed
steps = int(max_c*n*np.log(n)*np.log(n))

# %%
# Plot visited proportion over time for one graph
Simulator.plot_rw_on_rg_visited_prop(n, p, steps)

# %%
# Plot average visited proportion
k = 10
Simulator.plot_rw_on_rg_visited_prop(n, p, steps, k)
