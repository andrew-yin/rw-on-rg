# %%
# Setup
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
import numpy as np

sys.path.insert(0, '..')
plt.rcParams['figure.figsize'] = [10, 8]

from graph import Graph
from walkers import RandomWalker
from simulator import Simulator

# %%
# Set parameters
n = 1000
expected_deg = 10
p = expected_deg/n

# %%
# Plot visited proportion over time for one graph
Simulator.plot_rw_on_rg_visited_prop(n, p, d=expected_deg)

# %%
# Plot average visited proportion
k = 10
Simulator.plot_rw_on_rg_visited_prop(n, p, k, d=expected_deg)

# %%
props = []
k = 1
for n in [10, 100, 1000]:
    props.append(Simulator.simulate_rw_on_rg_visited_prop(n, expected_deg/n, k, comp_adj=True, d=expected_deg))

# %%
c = np.arange(0, 1, 0.1)
transformed_props = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wp/svz0rq8n0x10g6tdp4ctz5_80000gn/T/ipykernel_86951/3334491660.py in <module>
#       1 steps = len(prop)-1
#       2 c = np.arange(0, 0.1, 0.01)
# ----> 3 avg_at_each_c = [[prop[int(i*n*np.log(n)*np.log(n))] for i in c] for prop in props]
#       4 for i in avg_at_each_c:
#       5     plt.plot(c, i, label='k = {:d}, n={:d}, p={:.2f}'.format(50, n, p))
#
# NameError: name 'props' is not defined
