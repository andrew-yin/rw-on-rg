# %% [markdown]
# # Collaboration — 4/12/22

# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
import numpy as np
sys.path.insert(0, '..')


plt.rcParams['figure.figsize'] = [10, 8]
from graph import Graph
from collaboration import *

# %%
folder_path = "collaboration_4_12_22/"
simulate = True

# %% [markdown]
# ## 2 RWs, ER Random Graph

# %%
n = 100
d = 10
k = 100000

# %%
if simulate:
    graph = Graph.get_er_random_graph(n, d/n)
    t = 5*n
    collab_covered_avg1, single_covered_avg1 = simulate_rw_collab_vs_single(
        graph=graph, 
        collab_num=2, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"2rw_vs_1_rw_on_er_collab.csv", collab_covered_avg1, delimiter=',')
    np.savetxt(folder_path+"2rw_vs_1_rw_on_er_single.csv", single_covered_avg1, delimiter=',')
else:
    collab_covered_avg1 = np.loadtxt(folder_path+"2rw_vs_1_rw_on_er_collab.csv", delimiter=',')
    single_covered_avg1 = np.loadtxt(folder_path+"2rw_vs_1_rw_on_er_single.csv", delimiter=',')

# %%
c = 5
cs = np.arange(c, step=0.01)

scaled_single_covered_avg1 = np.array([single_covered_avg1[2*int(i*n)] for i in cs])
scaled_collab_covered_avg1 = np.array([collab_covered_avg1[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg1, label='Single Walk: S(2*c*n)')
plt.plot(cs, scaled_collab_covered_avg1, label='Collaboration: S1(c*n) + S2(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %%
diff1 = collab_covered_avg1 - np.array([single_covered_avg1[2*i] for i in range(c*n+1)])
scaled_diff1 = np.array([diff1[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff1, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %%
print("Is S1(t) + S2(t) >= S(2t) for all t? --", np.all(diff1 >= 0))
# Out:
# Is S1(t) + S2(t) >= S(2t) for all t? -- True

# %% [markdown]
# ## 3 RWs, ER Random Graph

# %%
if simulate:
    graph = Graph.get_er_random_graph(n, d/n)
    t = 3*n
    collab_covered_avg2, single_covered_avg2 = simulate_rw_collab_vs_single(
        graph=graph, 
        collab_num=3, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"3rw_vs_1_rw_on_er_collab.csv", collab_covered_avg2, delimiter=',')
    np.savetxt(folder_path+"3rw_vs_1_rw_on_er_single.csv", single_covered_avg2, delimiter=',')
else:
    collab_covered_avg2 = np.loadtxt(folder_path+"3rw_vs_1_rw_on_er_collab.csv", delimiter=',')
    single_covered_avg2 = np.loadtxt(folder_path+"3rw_vs_1_rw_on_er_single.csv", delimiter=',')

# %%
c = 3
cs = np.arange(c, step=0.01)

scaled_single_covered_avg2 = np.array([single_covered_avg2[3*int(i*n)] for i in cs])
scaled_collab_covered_avg2 = np.array([collab_covered_avg2[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg2, label='Single Walk: S(3*c*n)')
plt.plot(cs, scaled_collab_covered_avg2, label='Collaboration: S1(c*n) + S2(c*n) + S3(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %%
diff2 = collab_covered_avg2 - np.array([single_covered_avg2[3*i] for i in range(c*n+1)])
scaled_diff2 = np.array([diff2[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff2, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %% [markdown]
# ## 2 RW, 10-Reg

# %%
if simulate:
    graph = Graph.get_k_regular_random_graph(d, n)
    t = 5*n
    collab_covered_avg3, single_covered_avg3 = simulate_rw_collab_vs_single(
        graph=graph, 
        collab_num=2, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"2rw_vs_1_rw_on_10_reg_collab.csv", collab_covered_avg3, delimiter=',')
    np.savetxt(folder_path+"2rw_vs_1_rw_on_10_reg_single.csv", single_covered_avg3, delimiter=',')
else:
    collab_covered_avg3 = np.loadtxt(folder_path+"2rw_vs_1_rw_on_10_reg_collab.csv", delimiter=',')
    single_covered_avg3 = np.loadtxt(folder_path+"2rw_vs_1_rw_on_10_reg_single.csv", delimiter=',')

# %%
c = 5
cs = np.arange(c, step=0.01)

scaled_single_covered_avg3 = np.array([single_covered_avg3[2*int(i*n)] for i in cs])
scaled_collab_covered_avg3 = np.array([collab_covered_avg3[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg3, label='Single Walk: S(2*c*n)')
plt.plot(cs, scaled_collab_covered_avg3, label='Collaboration: S1(c*n) + S2(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()

# %%
diff3 = collab_covered_avg3 - np.array([single_covered_avg3[2*i] for i in range(c*n+1)])
scaled_diff3 = np.array([diff3[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff3, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()

# %% [markdown]
# ## 3 RWs, 10-Reg

# %%
if simulate:
    graph = Graph.get_k_regular_random_graph(d, n)
    t = 3*n
    collab_covered_avg4, single_covered_avg4 = simulate_rw_collab_vs_single(
        graph=graph, 
        collab_num=3, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"3rw_vs_1_rw_on_10_reg_collab.csv", collab_covered_avg4, delimiter=',')
    np.savetxt(folder_path+"3rw_vs_1_rw_on_10_reg_single.csv", single_covered_avg4, delimiter=',')
else:
    collab_covered_avg2 = np.loadtxt(folder_path+"3rw_vs_1_rw_on_10_reg_collab.csv", delimiter=',')
    single_covered_avg2 = np.loadtxt(folder_path+"3rw_vs_1_rw_on_10_reg_single.csv", delimiter=',')

# %%
c = 3
cs = np.arange(c, step=0.01)

scaled_single_covered_avg4 = np.array([single_covered_avg4[3*int(i*n)] for i in cs])
scaled_collab_covered_avg4 = np.array([collab_covered_avg4[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg4, label='Single Walk: S(3*c*n)')
plt.plot(cs, scaled_collab_covered_avg4, label='Collaboration: S1(c*n) + S2(c*n) + S3(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()

# %%
diff4 = collab_covered_avg4 - np.array([single_covered_avg4[3*i] for i in range(c*n+1)])
scaled_diff4 = np.array([diff4[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff4, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()

# %% [markdown]
# ## 3 RW Star, ER

# %%
if simulate:
    graph = Graph.get_er_random_graph(n, d/n)
    t = 3*n
    collab_covered_avg5, single_covered_avg5 = simulate_rw_star_collab_vs_single(
        graph=graph, 
        collab_num=3, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"3rw_star_vs_1_rw_on_er_collab.csv", collab_covered_avg5, delimiter=',')
    np.savetxt(folder_path+"3rw_star_vs_1_rw_on_er_single.csv", single_covered_avg5, delimiter=',')
else:
    collab_covered_avg5 = np.loadtxt(folder_path+"3rw_star_vs_1_rw_on_er_collab.csv", delimiter=',')
    single_covered_avg5 = np.loadtxt(folder_path+"3rw_star_vs_1_rw_on_er_single.csv", delimiter=',')

# %%
c = 3
cs = np.arange(c, step=0.01)

scaled_single_covered_avg5 = np.array([single_covered_avg5[3*int(i*n)] for i in cs])
scaled_collab_covered_avg5 = np.array([collab_covered_avg5[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg5, label='Single Walk: S(3*c*n)')
plt.plot(cs, scaled_collab_covered_avg5, label='Collaboration Star: S1(c*n) + S2(c*n) + S3(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %%
diff5 = collab_covered_avg5 - np.array([single_covered_avg5[3*i] for i in range(c*n+1)])
scaled_diff5 = np.array([diff5[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff5, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()

# %% [markdown]
# ## 3 RW Star, 10-Reg

# %%
if simulate:
    graph = Graph.get_k_regular_random_graph(d, n)
    t = 3*n
    collab_covered_avg6, single_covered_avg6 = simulate_rw_star_collab_vs_single(
        graph=graph, 
        collab_num=3, 
        k=k, 
        collab_steps_per_iter=t)
    
    np.savetxt(folder_path+"3rw_star_vs_1_rw_on_10_reg_collab.csv", collab_covered_avg6, delimiter=',')
    np.savetxt(folder_path+"3rw_star_vs_1_rw_on_10_reg_single.csv", single_covered_avg6, delimiter=',')
else:
    collab_covered_avg6 = np.loadtxt(folder_path+"3rw_star_vs_1_rw_on_10_reg_collab.csv", delimiter=',')
    single_covered_avg6 = np.loadtxt(folder_path+"3rw_star_vs_1_rw_on_10_reg_single.csv", delimiter=',')

# %%
c = 3
cs = np.arange(c, step=0.01)

scaled_single_covered_avg6 = np.array([single_covered_avg6[3*int(i*n)] for i in cs])
scaled_collab_covered_avg6 = np.array([collab_covered_avg6[int(i*n)] for i in cs])
plt.plot(cs, scaled_single_covered_avg6, label='Single Walk: S(3*c*n)')
plt.plot(cs, scaled_collab_covered_avg6, label='Collaboration Star: S1(c*n) + S2(c*n) + S3(c*n)')
plt.title("Visited Vertices vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, ER")
plt.show()

# %%
diff6 = collab_covered_avg6 - np.array([single_covered_avg6[3*i] for i in range(c*n+1)])
scaled_diff6 = np.array([diff6[int(i*n)] for i in cs])
plt.plot(cs, scaled_diff6, label='Difference: Collab - Single')
plt.title("Visited Vertices Difference vs. c")
plt.xlabel("c")
plt.ylabel("Visited Vertices")
plt.legend(title=f"n={n}, k={k}, 10-reg")
plt.show()
